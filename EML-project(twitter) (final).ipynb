# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Datasets\twitter\clean_d_tweets.csv")
df.head()
# Out:
#                date                                              tweet  day  \
# 0  16-05-2020 01:45  the real reason why you be sad you be attach t...    6
# 1  29-04-2020 06:42      my biggest problem be overthinking everything    3
# 2  29-04-2020 05:48  the worst sadness be the sadness you have teac...    3
# 3  29-04-2020 05:47  i cannot make you understand i cannot make any...    3
# 4  13-09-2019 00:52  i do not think anyone really understand how ti...    5
#
#    hour  nlikes  nreplies  nretweets
# 0     1   13731       219       5642
# 1     6   12583        98       6951
# 2     5   13350        51       7168
# 3     5   12926        56       8042
# 4     0   21160       111      13344

# %%
df1=pd.read_csv(r"C:\Datasets\twitter\clean_non_d_tweets.csv")
df1.head()
# Out:
#                date                                              tweet  day  \
# 0  09-08-2021 05:35                         touch pass be the new asmr    1
# 1  09-08-2021 04:36  12 years ago i call my dad and he give me some...    1
# 2  09-08-2021 04:28  there be 6500 languages yet i choose to only s...    1
# 3  09-08-2021 04:05  hey everyone ask for a raise today i be tell y...    1
# 4  08-08-2021 12:56  i invest in 47 startups in a year here be how ...    7
#
#    hour  nlikes  nreplies  nretweets
# 0     5      22         3          1
# 1     4     210         8         14
# 2     4     564        14         64
# 3     4    1052        28         74
# 4    12    2275        65        277

# %%
df.shape
# Out:
# (3082, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3082 entries, 0 to 3081
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3082 non-null   object
#  1   tweet      3075 non-null   object
#  2   day        3082 non-null   int64
#  3   hour       3082 non-null   int64
#  4   nlikes     3082 non-null   int64
#  5   nreplies   3082 non-null   int64
#  6   nretweets  3082 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 168.7+ KB

# %%
df.isnull().sum()
# Out:
# date         0
# tweet        7
# day          0
# hour         0
# nlikes       0
# nreplies     0
# nretweets    0
# dtype: int64

# %%
df1.shape
# Out:
# (4687, 7)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       4687 non-null   object
#  1   tweet      4670 non-null   object
#  2   day        4687 non-null   int64
#  3   hour       4687 non-null   int64
#  4   nlikes     4687 non-null   int64
#  5   nreplies   4687 non-null   int64
#  6   nretweets  4687 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 256.4+ KB

# %%
df1.isnull().sum()
# Out:
# date          0
# tweet        17
# day           0
# hour          0
# nlikes        0
# nreplies      0
# nretweets     0
# dtype: int64

# %%
df['label'] = 0 #for deppresed tweet
df.head()
# Out:
#                date                                              tweet  day  \
# 0  16-05-2020 01:45  the real reason why you be sad you be attach t...    6
# 1  29-04-2020 06:42      my biggest problem be overthinking everything    3
# 2  29-04-2020 05:48  the worst sadness be the sadness you have teac...    3
# 3  29-04-2020 05:47  i cannot make you understand i cannot make any...    3
# 4  13-09-2019 00:52  i do not think anyone really understand how ti...    5
#
#    hour  nlikes  nreplies  nretweets  label
# 0     1   13731       219       5642      0
# 1     6   12583        98       6951      0
# 2     5   13350        51       7168      0
# 3     5   12926        56       8042      0
# 4     0   21160       111      13344      0

# %%
df['depression'] = 'depressed'#depression column
df.head()
# Out:
#                date                                              tweet  day  \
# 0  16-05-2020 01:45  the real reason why you be sad you be attach t...    6
# 1  29-04-2020 06:42      my biggest problem be overthinking everything    3
# 2  29-04-2020 05:48  the worst sadness be the sadness you have teac...    3
# 3  29-04-2020 05:47  i cannot make you understand i cannot make any...    3
# 4  13-09-2019 00:52  i do not think anyone really understand how ti...    5
#
#    hour  nlikes  nreplies  nretweets  label depression
# 0     1   13731       219       5642      0  depressed
# 1     6   12583        98       6951      0  depressed
# 2     5   13350        51       7168      0  depressed
# 3     5   12926        56       8042      0  depressed
# 4     0   21160       111      13344      0  depressed

# %%
df1['label'] = 1#non-depressed
df1.head()
# Out:
#                date                                              tweet  day  \
# 0  09-08-2021 05:35                         touch pass be the new asmr    1
# 1  09-08-2021 04:36  12 years ago i call my dad and he give me some...    1
# 2  09-08-2021 04:28  there be 6500 languages yet i choose to only s...    1
# 3  09-08-2021 04:05  hey everyone ask for a raise today i be tell y...    1
# 4  08-08-2021 12:56  i invest in 47 startups in a year here be how ...    7
#
#    hour  nlikes  nreplies  nretweets  label
# 0     5      22         3          1      1
# 1     4     210         8         14      1
# 2     4     564        14         64      1
# 3     4    1052        28         74      1
# 4    12    2275        65        277      1

# %%
df1['depression'] = 'non depressed'#depression column
df1.head()
# Out:
#                date                                              tweet  day  \
# 0  09-08-2021 05:35                         touch pass be the new asmr    1
# 1  09-08-2021 04:36  12 years ago i call my dad and he give me some...    1
# 2  09-08-2021 04:28  there be 6500 languages yet i choose to only s...    1
# 3  09-08-2021 04:05  hey everyone ask for a raise today i be tell y...    1
# 4  08-08-2021 12:56  i invest in 47 startups in a year here be how ...    7
#
#    hour  nlikes  nreplies  nretweets  label     depression
# 0     5      22         3          1      1  non depressed
# 1     4     210         8         14      1  non depressed
# 2     4     564        14         64      1  non depressed
# 3     4    1052        28         74      1  non depressed
# 4    12    2275        65        277      1  non depressed

# %%
fdf=pd.concat([df,df1],axis=0)
fdf.head()
# Out:
#                date                                              tweet  day  \
# 0  16-05-2020 01:45  the real reason why you be sad you be attach t...    6
# 1  29-04-2020 06:42      my biggest problem be overthinking everything    3
# 2  29-04-2020 05:48  the worst sadness be the sadness you have teac...    3
# 3  29-04-2020 05:47  i cannot make you understand i cannot make any...    3
# 4  13-09-2019 00:52  i do not think anyone really understand how ti...    5
#
#    hour  nlikes  nreplies  nretweets  label depression
# 0     1   13731       219       5642      0  depressed
# 1     6   12583        98       6951      0  depressed
# 2     5   13350        51       7168      0  depressed
# 3     5   12926        56       8042      0  depressed
# 4     0   21160       111      13344      0  depressed

# %%
fdf.isnull().sum()
# Out:
# date           0
# tweet         24
# day            0
# hour           0
# nlikes         0
# nreplies       0
# nretweets      0
# label          0
# depression     0
# dtype: int64

# %%
fdf.dropna(inplace=True)

# %%
fdf.describe()
# Out:
#                day         hour         nlikes      nreplies     nretweets  \
# count  7745.000000  7745.000000    7745.000000   7745.000000   7745.000000
# mean      3.875274    10.742931    3056.255778     48.517753    470.000387
# std       1.950230     5.697265    9796.084655    243.599887   1346.530280
# min       1.000000     0.000000       0.000000      0.000000      0.000000
# 25%       2.000000     6.000000      38.000000      1.000000      6.000000
# 50%       4.000000    10.000000     257.000000      6.000000     49.000000
# 75%       6.000000    15.000000    2441.000000     25.000000    363.000000
# max       7.000000    23.000000  284059.000000  15004.000000  48180.000000
#
#              label
# count  7745.000000
# mean      0.602970
# std       0.489314
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
sns.countplot(x='label',data=fdf)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='hour',data=fdf,hue='depression')
plt.title('depression count by hour')
# Out:
# Text(0.5, 1.0, 'depression count by hour')

# %%
fdf['date'] = pd.to_datetime(fdf['date'])
fdf['month'] =fdf['date'].apply(lambda x: x.month)
fdf['year'] =fdf['date'].apply(lambda x: x.year)
fdf['day'] =fdf['date'].apply(lambda x: x.day)
fdf.head()
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_8884\1769506631.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   fdf['date'] = pd.to_datetime(fdf['date'])
#                  date                                              tweet  day  \
# 0 2020-05-16 01:45:00  the real reason why you be sad you be attach t...   16
# 1 2020-04-29 06:42:00      my biggest problem be overthinking everything   29
# 2 2020-04-29 05:48:00  the worst sadness be the sadness you have teac...   29
# 3 2020-04-29 05:47:00  i cannot make you understand i cannot make any...   29
# 4 2019-09-13 00:52:00  i do not think anyone really understand how ti...   13
#
#    hour  nlikes  nreplies  nretweets  label depression  month  year
# 0     1   13731       219       5642      0  depressed      5  2020
# 1     6   12583        98       6951      0  depressed      4  2020
# ...

# %%
fdf.drop(['date'],axis=1)
# Out:
#                                                   tweet  day  hour  nlikes  \
# 0     the real reason why you be sad you be attach t...   16     1   13731
# 1         my biggest problem be overthinking everything   29     6   12583
# 2     the worst sadness be the sadness you have teac...   29     5   13350
# 3     i cannot make you understand i cannot make any...   29     5   12926
# 4     i do not think anyone really understand how ti...   13     0   21160
# ...                                                 ...  ...   ...     ...
# 4682  cardi b want to trademark her catchphrase okur...   27     9    8183
# 4683  i will bet kellyanne and george conway have pr...   26     7   10606
# 4684  fan be always ask me how they can watch the ol...   25     5    3319
# 4685  ray romano be a hilarious comedian a kind soul...   25     2    2917
# 4686  muellers report may be finish but mine be out ...   24    14   10760
#
#       nreplies  nretweets  label     depression  month  year
# ...

# %%
numeric_fdf = fdf.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_fdf.corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr_matrix, cmap='Purples', annot=True)
# Out:
# <Axes: >

# %%
from sklearn.feature_extraction.text import TfidfVectorizer# Term Frequency-Inverse Document Frequency

# %%
tfd = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',stop_words= 'english',ngram_range=(1,2))

# %%
tfd.fit(fdf['tweet'])
text =tfd.transform(fdf['tweet'])

# %%
depressed_tweets = fdf[fdf['label'] == 1]['tweet']
non_depressed_tweets = fdf[fdf['label'] == 0]['tweet']
non_depressed_tfd = tfd.transform(depressed_tweets)
depressed_tfd = tfd.transform(non_depressed_tweets)

# %%
feature_names = tfd.get_feature_names_out()

# %%
non_depressed_scores = non_depressed_tfd.toarray().sum(axis=0)

# %%
depressed_scores = depressed_tfd.toarray().sum(axis=0)

# %%
from wordcloud import WordCloud
non_depressed_word_scores = dict(zip(feature_names, depressed_scores))
depressed_word_scores = dict(zip(feature_names, non_depressed_scores))

# %%
non_depressed_wordcloud = WordCloud(width=800,
                                height=400, background_color='white').generate_from_frequencies(depressed_word_scores)

# %%
plt.figure(figsize=(20, 5))
plt.imshow(non_depressed_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud for Non-Depressed Tweets')
# Out:
# Text(0.5, 1.0, 'WordCloud for Non-Depressed Tweets')

# %%
depressed_wordcloud = WordCloud(width=800, height=400, 
                                    background_color='white').generate_from_frequencies(non_depressed_word_scores)

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 2)
plt.imshow(depressed_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud for Depressed Tweets')
# Out:
# Text(0.5, 1.0, 'WordCloud for Depressed Tweets')

# %%
X = text 
y = fdf['label']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# X_train shape: (5421, 1000)
# y_train shape: (5421,)

# %%
y_train = np.ravel(y_train)

# %%
from sklearn.preprocessing import StandardScaler

X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_dense)
X_test_scaled = scaler.transform(X_test_dense)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.metrics import roc_auc_score,roc_curve, auc

# %%
#Logistic Regression
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred2 = lr.predict(X_test)
score2 = accuracy_score(y_test, y_pred2)
print("Accuracy:", score2)
# Out:
# Accuracy: 0.8270223752151463

# %%
print("Classifiaction Report")
print(classification_report(y_test, y_pred2))
# Out:
# Classifiaction Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77       953
#            1       0.81      0.92      0.86      1371
#
#     accuracy                           0.83      2324
#    macro avg       0.83      0.81      0.81      2324
# weighted avg       0.83      0.83      0.82      2324

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm2 = confusion_matrix(y_test, y_pred2)
print("Confusion matrix")
print(cm2)
# Out:
# Confusion matrix
# [[ 664  289]
#  [ 113 1258]]

# %%
lr_param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2', 'elasticnet'],
    'solver': ['saga', 'liblinear'], 
    'max_iter': [100, 200, 300]  
}

# %%
lr_random_search = RandomizedSearchCV(estimator=LogisticRegression(),
                                      param_distributions=lr_param_grid,
                                      n_iter=10,  # Number of random combinations
                                      cv=3, 
                                      verbose=2, 
                                      random_state=42, 
                                      n_jobs=-1)


lr_random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# C:\Users\manas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 18 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\manas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manas\anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
print(f"Best parameters for LogisticRegression: {lr_random_search.best_params_}")
# Out:
# Best parameters for LogisticRegression: {'solver': 'saga', 'penalty': 'l2', 'max_iter': 200, 'C': 1}

# %%
best_lr_classifier = lr_random_search.best_estimator_

# %%
y_pred = best_lr_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Logistic regression after Tuning:",accuracy)
# Out:
# Accuracy of Logistic regression after Tuning: 0.8261617900172117

# %%
print("\nClassification Report logistic:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report logistic:
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77       953
#            1       0.81      0.92      0.86      1371
#
#     accuracy                           0.83      2324
#    macro avg       0.83      0.81      0.81      2324
# weighted avg       0.83      0.83      0.82      2324

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 663  290]
#  [ 114 1257]]

# %%
#Random Forest Algorithm
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Random Forest:",accuracy)
# Out:
# Accuracy of Random Forest: 0.7956110154905336

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76       953
#            1       0.84      0.81      0.82      1371
#
#     accuracy                           0.80      2324
#    macro avg       0.79      0.79      0.79      2324
# weighted avg       0.80      0.80      0.80      2324

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 736  217]
#  [ 258 1113]]

# %%
rf_param_grid = {
    'n_estimators': [50, 100, 200, 500],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
rf_random_search = RandomizedSearchCV(estimator=RandomForestClassifier(),
                                      param_distributions=rf_param_grid,
                                      n_iter=20,  # Number of random combinations
                                      cv=3,  # 3-fold cross-validation
                                      verbose=2, 
                                      random_state=42, 
                                      n_jobs=-1)
rf_random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=20,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 10, 20, 30, 40],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [50, 100, 200, 500]},
#                    random_state=42, verbose=2)

# %%
print(f"Best parameters for RandomForest: {rf_random_search.best_params_}")
print("Best Cross-Validation Score: ",rf_random_search.best_score_ )
# Out:
# Best parameters for RandomForest: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': None, 'bootstrap': True}
# Best Cross-Validation Score:  0.7814056447149973

# %%
best_rf_classifier = rf_random_search.best_estimator_

# %%
y_pred = best_rf_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Random Forest after Tuning:",accuracy)
# Out:
# Accuracy of Random Forest after Tuning: 0.7969018932874354

# %%
print("\nClassification Report random forest:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report random forest:
#               precision    recall  f1-score   support
#
#            0       0.78      0.71      0.74       953
#            1       0.81      0.86      0.83      1371
#
#     accuracy                           0.80      2324
#    macro avg       0.79      0.78      0.79      2324
# weighted avg       0.80      0.80      0.80      2324

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 673  280]
#  [ 192 1179]]

# %%
#Decision Tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)

# %%
dt_classifier.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn import tree
plt.figure(figsize=(20,10))
tree.plot_tree(dt_classifier, 
               max_depth=3, 
               fontsize=10, 
               feature_names=tfd.get_feature_names_out(),  
               class_names=['depressed', 'non depressed'], 
               filled=True)
plt.show()

# %%
y_pred = dt_classifier.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Decision Tree: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy of Decision Tree: 74.48%

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.76      0.71       953
#            1       0.82      0.73      0.77      1371
#
#     accuracy                           0.74      2324
#    macro avg       0.74      0.75      0.74      2324
# weighted avg       0.75      0.74      0.75      2324

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 728  225]
#  [ 368 1003]]

# %%
dt_param_grid = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']  
}

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)

# %%
dt_random_search = RandomizedSearchCV(estimator=DecisionTreeClassifier(),
                                      param_distributions=dt_param_grid,
                                      n_iter=10,  # Number of random combinations
                                      cv=3, 
                                      verbose=2, 
                                      random_state=42, 
                                      n_jobs=-1)

dt_random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10]},
#                    random_state=42, verbose=2)

# %%
print("Best Parameters:", dt_random_search.best_params_)
print("Best Cross-Validation Score: ",dt_random_search.best_score_)
# Out:
# Best Parameters: {'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': None, 'criterion': 'gini'}
# Best Cross-Validation Score:  0.7153661686035787

# %%
best_dt_classifier = dt_random_search.best_estimator_

# %%
y_pred = best_dt_classifier.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Decision Tree after Tuning: ",accuracy)
# Out:
# Accuracy of Decision Tree after Tuning:  0.5731497418244407

# %%
print("\nClassification Report decision tree:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report decision tree:
#               precision    recall  f1-score   support
#
#            0       0.49      0.86      0.62       953
#            1       0.80      0.37      0.51      1371
#
#     accuracy                           0.57      2324
#    macro avg       0.64      0.62      0.57      2324
# weighted avg       0.67      0.57      0.55      2324

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[823 130]
#  [862 509]]

# %%
#Gradientboosting
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
gb_classifier = GradientBoostingClassifier(random_state=42)

# %%
gb_classifier.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred = gb_classifier.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Gradient Boosting: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy of Gradient Boosting: 72.72%

# %%
print("\nClassification Report gradient :")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report gradient :
#               precision    recall  f1-score   support
#
#            0       0.83      0.42      0.56       953
#            1       0.70      0.94      0.80      1371
#
#     accuracy                           0.73      2324
#    macro avg       0.77      0.68      0.68      2324
# weighted avg       0.75      0.73      0.70      2324

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[ 399  554]
#  [  80 1291]]

# %%
param_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3],
    'max_depth': [3, 4, 5, 6, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'subsample': [0.6, 0.8, 1.0],  
    'max_features': ['auto', 'sqrt', 'log2']  
}

# %%
gb_classifier = GradientBoostingClassifier(random_state=42)

# %%
gb_random_search = RandomizedSearchCV(estimator=gb_classifier,
                                      param_distributions=param_grid,
                                      n_iter=20, 
                                      cv=3, 
                                      verbose=2, 
                                      random_state=42,
                                      n_jobs=-1)

# %%
gb_random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# C:\Users\manas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 27 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\manas\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\manas\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
best_gb_model = gb_random_search.best_estimator_

# %%
y_pred = best_gb_model.predict(X_test_scaled)

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.79      0.69       953
#            1       0.82      0.66      0.73      1371
#
#     accuracy                           0.71      2324
#    macro avg       0.72      0.72      0.71      2324
# weighted avg       0.74      0.71      0.71      2324

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[753 200]
#  [469 902]]

# %%
# SVC model
svc_classifier = SVC(kernel='linear', C=1)  
svc_classifier.fit(X_train, y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
y_pred = svc_classifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 675  278]
#  [ 142 1229]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.76       953
#            1       0.82      0.90      0.85      1371
#
#     accuracy                           0.82      2324
#    macro avg       0.82      0.80      0.81      2324
# weighted avg       0.82      0.82      0.82      2324

# %%
param_dist = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf'], 'gamma': ['scale', 'auto']}

# %%
random_search = RandomizedSearchCV(SVC(), param_distributions=param_dist, n_iter=10, cv=5,
                                   verbose=2, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'rbf']},
#                    random_state=42, verbose=2)

# %%
print(random_search.best_params_)
# Out:
# {'kernel': 'rbf', 'gamma': 'scale', 'C': 1}

# %%
y_pred = random_search.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       953
#            1       0.84      0.89      0.87      1371
#
#     accuracy                           0.84      2324
#    macro avg       0.84      0.82      0.83      2324
# weighted avg       0.84      0.84      0.83      2324

# %%
#ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# %%
model = Sequential()
model.add(Dense(units=64, activation='relu', input_shape=(X_train.shape[1],)))#input layer
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                64064
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_2 (Dense)             (None, 2)                 66
#
# ...
# Total params: 66,210
# Trainable params: 66,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=32,validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 170/170 [==============================] - 1s 4ms/step - loss: 0.5785 - accuracy: 0.6763 - val_loss: 0.4038 - val_accuracy: 0.8253
# Epoch 2/20
# 170/170 [==============================] - 1s 3ms/step - loss: 0.3466 - accuracy: 0.8469 - val_loss: 0.3679 - val_accuracy: 0.8339
# Epoch 3/20
# 170/170 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.8688 - val_loss: 0.3798 - val_accuracy: 0.8335
# Epoch 4/20
# 170/170 [==============================] - 1s 3ms/step - loss: 0.2581 - accuracy: 0.8853 - val_loss: 0.3927 - val_accuracy: 0.8244
# Epoch 5/20
# 170/170 [==============================] - 1s 3ms/step - loss: 0.2298 - accuracy: 0.8980 - val_loss: 0.4130 - val_accuracy: 0.8292
# Epoch 6/20
# 170/170 [==============================] - 0s 3ms/step - loss: 0.2053 - accuracy: 0.9129 - val_loss: 0.4436 - val_accuracy: 0.8287
# Epoch 7/20
# ...

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8240 - accuracy: 0.8128
# Test accuracy: 0.812822699546814

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 73/73 [==============================] - 0s 1ms/step

# %%
print(f"Predicted classes: {y_pred_classes[:5]}")
print(f"True classes: {y_true[:5]}")#0:non:depressed,1:Depressed
# Out:
# Predicted classes: [0 0 0 1 0]
# True classes: [0 0 1 1 0]

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 73/73 [==============================] - 0s 1ms/step

# %%
print(confusion_matrix(y_true, y_pred))
# Out:
# [[ 725  228]
#  [ 207 1164]]

# %%
print(classification_report(y_true, y_pred, target_names=['Non-Depressed', 'Depressed']))
# Out:
#                precision    recall  f1-score   support
#
# Non-Depressed       0.78      0.76      0.77       953
#     Depressed       0.84      0.85      0.84      1371
#
#      accuracy                           0.81      2324
#     macro avg       0.81      0.80      0.81      2324
#  weighted avg       0.81      0.81      0.81      2324

# %%
#combinig by stacking

# %%
base_estimators = [
    ('lr', LogisticRegression()),
    ('dt', DecisionTreeClassifier()),
    ('rf', RandomForestClassifier()),
    ('svc', SVC(probability=True)),
    ('gb', GradientBoostingClassifier())
]

# %%
meta_model = LogisticRegression()
stacking_clf = StackingClassifier(estimators=base_estimators, final_estimator=meta_model)
stacking_clf.fit(X_train, y_train)
y_pred = stacking_clf.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred)}")
# Out:
# Accuracy: 0.8407917383820999
# Confusion Matrix:
# [[ 746  207]
#  [ 163 1208]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       953
#            1       0.85      0.88      0.87      1371
#
#     accuracy                           0.84      2324
#    macro avg       0.84      0.83      0.83      2324
# weighted avg       0.84      0.84      0.84      2324

# %%
data = {
    'Model': ['Logistic Regression', 'Random Forest', 'Decision Tree', 
              'Gradient Boosting', 'SVM', 'ANN'],
    'Accuracy': [0.83, 0.80, 0.57, 0.71, 0.84, 0.81],
    'Precision (Depressed)': [0.81, 0.81, 0.80, 0.82, 0.84, 0.84],
    'Recall (Depressed)': [0.92, 0.86, 0.37, 0.66, 0.89, 0.85],
    'F1-Score (Depressed)': [0.86, 0.83, 0.51, 0.73, 0.87, 0.84]
}
dfp = pd.DataFrame(data)

dfp.set_index('Model', inplace=True)

dfp
# Out:
#                      Accuracy  Precision (Depressed)  Recall (Depressed)  \
# Model
# Logistic Regression      0.83                   0.81                0.92
# Random Forest            0.80                   0.81                0.86
# Decision Tree            0.57                   0.80                0.37
# Gradient Boosting        0.71                   0.82                0.66
# SVM                      0.84                   0.84                0.89
# ANN                      0.81                   0.84                0.85
#
#                      F1-Score (Depressed)
# Model
# Logistic Regression                  0.86
# Random Forest                        0.83
# Decision Tree                        0.51
# Gradient Boosting                    0.73
# SVM                                  0.87
# ANN                                  0.84

# %% [markdown]
# # Conclusion

# %% [markdown]
# #### The analysis of various machine learning models for predicting depression from Twitter data reveals that the Support Vector Machine (SVM) achieved the highest accuracy of 84%, along with robust precision and recall metrics. In contrast, the Decision Tree model performed poorly, with an accuracy of only 57%, indicating its unsuitability for this specific task without further tuning.
#
# Logistic Regression and Artificial Neural Networks also showed strong performance, making them viable alternatives.
